# %%
import numpy as np
import pandas as pd
import pickle

# with open('bin/tag_meta.p', 'rb') as f:
#     tag_meta, tag_meta_inverse = pickle.load(f)

# %%
head = pd.read_json('submission/lightknn_100_idf_04_head.json', orient='records')
tail = pd.read_json('submission/lightknn_100_idf_04_tail.json', orient='records')
display(head, tail)
ans = pd.concat([head, tail], ignore_index=True)
ans.to_json('submission/lightknn_100_idf_04.json', orient='records')
# Out:
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 12995  136683  [16382, 349306, 660725, 595188, 283888, 496879...
# 12996    5216  [16382, 349306, 660725, 595188, 283888, 496879...
# 12997   68038  [370796, 258919, 522825, 298103, 170317, 24698...
# 12998   60325  [675115, 407828, 671830, 26083, 302646, 650494...
# 12999   20545  [16382, 349306, 660725, 595188, 283888, 496879...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 12995       [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 12996       [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 12997        [발라드, 이별, 사랑, 슬픔, 추억, 설렘, 회상, 기분전환, 감성, 까페]
# 12998      [추억, 기분전환, 발라드, 회상, 휴식, 힐링, 드라이브, 멜론, 사랑, 감성]
# 12999       [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
#
# [13000 rows x 3 columns]
#            id                                              songs  \
# 0      120241  [658227, 200687, 54755, 335756, 576559, 529748...
# 1      134333  [654757, 88503, 123465, 492678, 118219, 295250...
# 2      151400  [675115, 44603, 643628, 77951, 35703, 11657, 6...
# 3      147692  [518420, 318530, 114119, 443914, 375431, 60363...
# 4       24748  [588471, 253386, 447424, 479311, 268138, 51234...
# ...       ...                                                ...
# 10010  101722  [339802, 116573, 286273, 459866, 413189, 57790...
# 10011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 10012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 10013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 10014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [방탄소년단, 아이돌, 기분전환, 신나는, 드라이브, BTS, 여행, 휴식, 봄, 감성]
# 1       [OST, 추억, 회상, 사랑, 드라마ost, 기분전환, 발라드, 설렘, 이별, 휴식]
# 2            [잔잔한, 가을, 발라드, 새벽, 이별, 회상, 밤, 힐링, 휴식, 기분전환]
# 3      [신나는, 댄스, 기분전환, 걸그룹, 아이돌, 운동, 드라이브, 여자아이돌, 여행,...
# 4         [아이돌, 기분전환, 댄스, 발라드, 신나는, 드라이브, 휴식, 힙합, 랩, 운동]
# ...                                                  ...
# 10010         [새벽, 밤, 이별, 슬픔, 힐링, 발라드, 휴식, 감성, 기분전환, 인디]
# 10011      [사랑, 추억, 엄마, 부모님, 회상, 힐링, 휴식, 잔잔한, 어버이날, 발라드]
# 10012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 10013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 10014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [10015 rows x 3 columns]

# %%
ans = pd.read_json('submission/lightknn_100_cos_a03_b07.json', orient='records')
idx = []
for i in ans.index:
    length = len(ans.tags[i])
    if length != 10:
        idx.append(i)
        for k in range(10-length):
            ans.tags[i].append(k)
display(ans.tags[idx])
ans.to_json('submission/results.json', orient='records')
# Out:
# 2948               [뉴에이지, 뉴에이, 0, 1, 2, 3, 4, 5, 6, 7]
# 3312               [뉴에이지, 뉴에이, 0, 1, 2, 3, 4, 5, 6, 7]
# 3908               [뉴에이지, 뉴에이, 0, 1, 2, 3, 4, 5, 6, 7]
# 5452               [뉴에이지, 뉴에이, 0, 1, 2, 3, 4, 5, 6, 7]
# 5474                  [겨울, 재즈, 0, 1, 2, 3, 4, 5, 6, 7]
# 18110              [뉴에이지, 뉴에이, 0, 1, 2, 3, 4, 5, 6, 7]
# 18638                 [겨울, 재즈, 0, 1, 2, 3, 4, 5, 6, 7]
# 21410    [해외차트, 국내, 국내차트, 년대, 멜론차트, 실시간차트, 0, 1, 2, 3]
# 22189                 [겨울, 재즈, 0, 1, 2, 3, 4, 5, 6, 7]
# Name: tags, dtype: object

# %%
first = pd.read_json('submission/lightknn_100_idf_rho04a05b05_head.json', orient='records')
second = pd.read_json('submission/lightknn_100_idf_rho04a05b05_tail.json', orient='records')
third = pd.read_json('submission/lightknn_100_idf_rho04a05b05_third.json', orient='records')
ans = pd.concat([first, second, third], ignore_index=True)
display(ans)
for i in ans.index:
    temp = []
    for tag in ans.tags[i]:
        temp.append(tag_meta_inverse[tag])
    ans.at[i, 'tags'] = temp
display(ans)
idx = []
for i in ans.index:
    length = len(ans.tags[i])
    if length != 10:
        idx.append(i)
        for k in range(10-length):
            ans.tags[i].append(k)
display(ans.tags[idx])
ans.to_json('submission/lightknn_100_idf_rho04a05b05.json', orient="records")
# Out:
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [116573, 366786, 22845, 449244, 95485, 245317,...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [86, 2928, 2737, 1089, 1, 21, 5250, 3574, 3577...
# 1             [21, 122, 17, 57, 20, 85, 110, 192, 1, 67]
# 2                [122, 1, 2, 31, 28, 71, 59, 60, 30, 67]
# 3              [122, 67, 30, 4, 31, 60, 85, 21, 110, 59]
# 4      [326, 947, 949, 30, 1454, 2355, 2680, 3542, 12...
# ...                                                  ...
# 23010           [60, 59, 110, 20, 67, 1, 30, 31, 21, 28]
# 23011          [124, 3161, 20, 473, 30, 4, 1, 67, 60, 2]
# 23012        [23, 309, 18, 21, 17, 110, 96, 85, 112, 67]
# 23013      [358, 110, 20, 4, 21, 493, 65, 157, 654, 258]
# 23014       [70, 30, 217, 71, 627, 21, 922, 626, 67, 17]
#
# [23015 rows x 3 columns]
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [116573, 366786, 22845, 449244, 95485, 245317,...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 23010          [새벽, 밤, 휴식, 힐링, 감성, 추억, 사랑, 이별, 기분전환, 슬픔]
# 23011         [위로, 엄마, 힐링, 부모님, 사랑, 잔잔한, 추억, 감성, 새벽, 회상]
# 23012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 23013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 23014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [23015 rows x 3 columns]
# 491               [힙합, 힙합엘이, 흑인음악, 알앤비, R, 추억, 0, 1, 2, 3]
# 1479             [힙합, 쇼미더머니, 알앤비, 이것저것, 국힙, 0, 1, 2, 3, 4]
# 5463     [힙합, HIPHOPLE, 흑인음악, 알앤비, R, 서울소울페스티벌, 서소페, 0,...
# 9375     [피쉬슈즈, 인디, 인디스트리트, indie, 레이브릭스, ByeByeBadman,...
# 9535     [나만의Best3, 피쉬슈즈, 인디스트리트, 미러볼뮤직, 케이인디차트, 낭만, 추억...
# 10787    [나만의Best3, 인디, 인디스트리트, indie, 신해경, 피터팬콤플렉스, 전지...
# 11290          [힙합, 힙합엘이, 흑인음악, 알앤비, R, 클럽, 드라이브, 0, 1, 2]
# 12162    [힙합, primary, HipHop, M에센셜, 프라이머리, Rap, 기분전환, ...
# 19479                  [힙합, 감성, 부드러움, 0, 1, 2, 3, 4, 5, 6]
# Name: tags, dtype: object

# %%
a = pd.read_json('submission/lightknn_100_idf_04.json', orient='records')
b = pd.read_json('submission/lightknn_100_idf_rho04a05b05.json', orient='records')
display(a, b)
ans = a.copy()
for i in ans.index:
    ans.at[i, 'tags'] = b.tags[i]
display(ans)
ans.to_json('submission/lightknn_100_idf_rho04_tags-a05b05.json', orient='records')
# Out:
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [339802, 116573, 286273, 459866, 413189, 57790...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 23010         [새벽, 밤, 이별, 슬픔, 힐링, 발라드, 휴식, 감성, 기분전환, 인디]
# 23011      [사랑, 추억, 엄마, 부모님, 회상, 힐링, 휴식, 잔잔한, 어버이날, 발라드]
# 23012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 23013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 23014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [23015 rows x 3 columns]
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [116573, 366786, 22845, 449244, 95485, 245317,...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 23010          [새벽, 밤, 휴식, 힐링, 감성, 추억, 사랑, 이별, 기분전환, 슬픔]
# 23011         [위로, 엄마, 힐링, 부모님, 사랑, 잔잔한, 추억, 감성, 새벽, 회상]
# 23012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 23013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 23014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [23015 rows x 3 columns]
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [339802, 116573, 286273, 459866, 413189, 57790...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 23010          [새벽, 밤, 휴식, 힐링, 감성, 추억, 사랑, 이별, 기분전환, 슬픔]
# 23011         [위로, 엄마, 힐링, 부모님, 사랑, 잔잔한, 추억, 감성, 새벽, 회상]
# 23012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 23013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 23014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [23015 rows x 3 columns]

# %%
val = pd.read_json('res/val.json')
combined = pd.read_json('submission/lightknn_100_idf_rho04_tags-a05b05.json', orient='records')
b = pd.read_json('submission/lightknn_100_idf_rho04a05b05.json', orient='records')
for i in val.index:
    if val.songs[i] == []:
        combined.at[i, 'songs'] = b.songs[i]
display(combined)
combined.to_json('submission/lightknn_100_idf_rho04_tags-a05b05-songs_upgraded.json', orient='records')
# Out:
#            id                                              songs  \
# 0      118598  [207912, 623047, 422438, 703323, 638488, 32221...
# 1      131447  [16382, 349306, 660725, 595188, 283888, 496879...
# 2       51464  [533739, 214521, 610218, 457500, 456474, 40277...
# 3       45144  [144663, 367963, 174749, 224921, 116114, 19533...
# 4       79929  [211220, 412769, 445299, 106129, 70314, 526037...
# ...       ...                                                ...
# 23010  101722  [339802, 116573, 286273, 459866, 413189, 57790...
# 23011  122127  [352228, 138932, 4173, 473514, 630552, 48209, ...
# 23012   77438  [274504, 679436, 140867, 459256, 571016, 69631...
# 23013   36231  [651788, 354737, 64680, 532729, 375318, 81796,...
# 23014   65189  [457124, 250, 204547, 25012, 104065, 586556, 1...
#
#                                                     tags
# 0      [OST, 디즈니, 애니메이션, 영화, 추억, 기분전환, 동심, 디즈니OST, 픽사...
# 1           [기분전환, 발라드, 드라이브, 힙합, 힐링, 카페, 휴식, 랩, 추억, 감성]
# 2               [발라드, 추억, 회상, 이별, 슬픔, 설렘, 밤, 새벽, 사랑, 감성]
# 3            [발라드, 감성, 사랑, 잔잔한, 이별, 새벽, 카페, 기분전환, 휴식, 밤]
# 4      [CCM, 찬양, 은혜, 사랑, 예배, 국내ccm, 교회, 찬송가, 위로, 파워DJ...
# ...                                                  ...
# 23010          [새벽, 밤, 휴식, 힐링, 감성, 추억, 사랑, 이별, 기분전환, 슬픔]
# 23011         [위로, 엄마, 힐링, 부모님, 사랑, 잔잔한, 추억, 감성, 새벽, 회상]
# 23012    [팝, 팝송, Pop, 기분전환, 드라이브, 휴식, 신나는, 카페, 매장음악, 감성]
# 23013    [클래식, 휴식, 힐링, 잔잔한, 기분전환, 피아노, 가을, 연주곡, 집중, 자장가]
# 23014      [봄, 사랑, 벚꽃, 설렘, 봄노래, 기분전환, 봄날, 봄캐롤, 감성, 드라이브]
#
# [23015 rows x 3 columns]
